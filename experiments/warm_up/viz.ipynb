# %%
from utils.viz import subplots_from_seed, plot_correlations_from_seed

# %%
subplots_from_seed(8, ['NC1', 'NC2', 'NC3', 'NC4'], 'test_acc', labely2='test accuracy on full dataset', trunc_rate = 0.0, interp = None)

# %%
subplots_from_seed(8, ['NC1', 'NC2', 'NC3', 'NC4'], 'train_time', labely2='training time on full dataset', trunc_rate = 0.1, interp = None)

# %%
plot_correlations_from_seed(7, 'test_acc', ['NC1', 'NC2', 'NC3', 'NC4'])
