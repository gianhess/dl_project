# %%
from utils.viz import *

# %% [markdown]
# # Correlation between the PL and NC

# %%
results = get_results_df(10)

# %% [markdown]
# ## Complete picture

# %%
plot_pairwise_subplots(results, ['NC1', 'NC2', 'NC3', 'NC4'], 'test_acc', interp=None, labely2='test accuracy on Full Dataset')

# %% [markdown]
# ## Beginning

# %%
plot_pairwise_subplots(results, ['NC1', 'NC2', 'NC3', 'NC4'], 'test_acc', interp=100, labely2='test accuracy on Full Dataset', end=100)

# %% [markdown]
# ## End

# %%
plot_pairwise_subplots(results, ['NC1', 'NC2', 'NC3', 'NC4'], 'test_acc', interp=100, labely2='test accuracy on Full Dataset', start=100)

# %% [markdown]
# ## Correlation across time:

# %% [markdown]
# Looking more deeply into that, considering different random seeds and a sliding window of 100 epochs we can confirm the intuition.
# Correlation is extremely high at the beginning of the training (the first 100 epochs) and then start to deteriorate.

# %%
plot_correlation([get_results_df(i) for i in range(7,11)], 'NC1', 'test_acc', 100)

# %% [markdown]
# ### Shrink and Perturb

# %% [markdown]
# The same considerations holds also after shrinking and perturbing the weights.

# %%
plot_correlation([get_results_df(i) for i in range(7,11)], 'NC1_SP', 'test_acc_SP', 100)

# %% [markdown]
# ## Conclusion: There is a clear relationship at the beginning, can we exploit this?

# %%
metric_names = ['test_acc', 'test_acc_SP', 'test_acc_reg']
y_label = 'Test Accuracy on Full dataset'
metric_labels = ['normal', 'shrink and perturb', 'NC1 regularized']
plot_metrics_with_error_bars( metric_names, y_label, metric_labels)

# %%
metric_names = ['test_acc_half', 'test_acc_half_SP', 'test_acc_half_reg']
y_label = 'Test Accuracy on Half dataset'
metric_labels = ['normal', 'shrink and perturb', 'NC1 regularized']
plot_metrics_with_error_bars( metric_names, y_label, metric_labels)
